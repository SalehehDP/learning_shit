# %% [markdown]
# In react when you'r *update state base on the previous value of that state* ypu should *pass a function* to that state updating function
#
# the funtion will be called  by react and automatically get current state value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# what is the problem :
# ![image.png](attachment:image.png)

# %% [markdown]
# In use :
#
# ![image.png](attachment:image.png)
#
# if insted we do this :
#
# now automatically get the latest state value at the point of time where this scheduled update is executed
#
# ![image-2.png](attachment:image-2.png)
#
# when you pass function you simply have a guarantee by React that you alwayse working with the latest available state value .
