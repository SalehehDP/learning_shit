# %% [markdown]
# Working with *object or array state* values :
#
# it's strongly recommended , you update that state in an immutable way =>
# which simply means you creat a copy
#
#
# ![image.png](attachment:image.png)
