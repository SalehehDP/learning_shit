# %% [markdown]
# Section component:
#
# as you can see in Examples and CoreConcepts component we have same structure

# %%
<section id="section_id">
    <title> section tilte </title>
    ../content../
</section>

# %% [markdown]
# so we can have Section component becuse this structure can be use alot ...
#
# you can see the component in 1-starting_project/src/components/Section.jsx

# %% [markdown]
# some element that is same in Section and section component are not forwarded magicly and should be done by hand and we are lazy soooo ....
#
# ![image.png](attachment:image.png)
#
# we will use forwardewd prpos or proxy prpos
