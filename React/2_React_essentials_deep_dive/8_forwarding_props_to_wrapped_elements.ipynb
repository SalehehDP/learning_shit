# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# this can be a very usefull pattern when building **wrapper components**   => a very *flexable* wrapper component
#
#
# hit this pattern we forward props to some inner element im our custom component
