# %% [markdown]
# props.childeren , this is built-in

# %%
<ComponentName> lalalala!! </ComponentName>

# %% [markdown]
# then we can have this *lalalala!* with props.childeren in component function
#
# we always get childeren in props and it **refer to wich ever content you have between tags**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# component composition
#
# از این حالت گاهی به این دلیل استفاده میشه چون شبیه به حالت HTML باقی بماند
# به عنوان مثال ایجاد برای ایجاد کردن button

# %% [markdown]
# ![image.png](attachment:image.png)
