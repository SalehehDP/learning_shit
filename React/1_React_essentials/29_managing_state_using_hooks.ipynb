# %% [markdown]
# To update UI we need a way to tell React update your self you piss of shitttt(didn't have good sleep last night)
#
#     STATE
#
# React Hook : every function that startwith use
#
# 1- they should be called (*directly) in component function or insider other react hook
#
# 2- only call hook in top level
#
#
# //we can build our own hook ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import { useState } from "react";
function App() {
    useState();

    function nestedFunction(){
        //useState();  not allowed
    } 
    

    /*
    . 
    .
    .
    */
}

# %% [markdown]
# useState hook :
#
#    is one of the most important Hooks , becuase it's allow us to mange *some component specific state* , wich is simply some data stored by React .which when changed , will trigger component function to re-execute
#
#  - what use
#
#     with this hook you tell react to re-execute the function component when the data change
#
#  - how to use
#
#    const [X , setX] =  useState(defualt_value)
#
#    defualt_value :  use by React in first run of the component funcion.
#
#    X: value , will be the current data snapshot => in first run it's will be equal to defualt_value
#
#    setX : function , provided by React that can be exected to update the sorted value => calling this function will tell React component function must be executed again.

# %%
const [selectedTopic , setSelecetedTopic] = useState("please click a button");
 // we use const becuase only when component re-exctue these value will change .

# %% [markdown]
#  flow :
#
# click on button -> call setSelectedTopic -> React schedules , this state update -> re-executes component function -> naw value in selectedTopic is avaiable
