# %% [markdown]
# * Making component reusable with prop:
#
#     Props : pass data into components, use data in there
#
# ** we don't call and run component function , we use them as html element .... React will call the actula function.
#
# ** React is passing value(type : object) to components function

# %%
function CoreConcept(props) { // you can name props anything you want but props fit better 
    return (
        <div>
            <Image src={props.img} />
            <title>{props.title}</title>
            <p>{props.description}</p>
          </div>
    );
}

// how to use 
<CoreConcept 
    title=""
    description=""
    img={ }
    />

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# html attributes   --React-->   singel object   --component function-->   name props
#
#
# attributes =""  --React-->  {attributes =""}   --component function-->  props.attributes
