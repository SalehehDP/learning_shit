# %% [markdown]
# Get closer look at what is happening

# %%
import ReactDOM from "react-dom/client";  // ReactDOM is responsible for outputing the App component ,on screen

import App from "./App.jsx";
import "./index.css";

const entryPoint = document.getElementById("root"); // exsiting html element , getElementById "root"
ReactDOM.createRoot(entryPoint).render(<App />); //passing App to render method , render App and then put it in root 

// set element div as root for react project

# %% [markdown]
# **Root component** (App) : The first copmonent to be analyzed and render by react .... but we can have *Nested component* in it.
#
# **Nested component** (Header , ...): child component
#
#
# **Component Hierarchy** : tree components
# ![image.png](attachment:image.png)
#
#
#
# React render all component at the end it will be just HTML
#
# why start with appercase => to tell React it's not a *built_in component* and it's *custom component* => use as elements
#
# ![image-2.png](attachment:image-2.png)
